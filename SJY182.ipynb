# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# partial path of each URL from where the data is obtained
BASE_URL_PATH = [
'https://flightaware.com/live/flight/SJY182/history/20210109/0640Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20210104/0640Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20201217/0640Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20201215/0640Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20201212/0640Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20201210/0640Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20201205/0640Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20201203/0640Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20201202/0915Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20201201/0915Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20201128/0750Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20201127/0915Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20201125/0915Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20201124/0750Z/WIII/WIOO',
'https://flightaware.com/live/flight/SJY182/history/20201121/0750Z/WIII/WIOO'
]

# %%
# add '/tracklog' to each partial URL path
BASE_URL = []
for path in BASE_URL_PATH:
    url_path = path + '/tracklog'
    BASE_URL.append(url_path)

# %%
# a list of table (df) is created as follows
df = []
for b in BASE_URL:
    # read the table in each webpage
    dat = pd.read_html(b) 
    df.append(dat)

# %%
# extract the date from the URL path. The data will be identified by the date
tab_name =[]
for t in BASE_URL_PATH:
    dat_name = t.split('/')[7]
    tab_name.append(dat_name)

# %%
tab_name
# Out:
# ['20210109',
#  '20210104',
#  '20201217',
#  '20201215',
#  '20201212',
#  '20201210',
#  '20201205',
#  '20201203',
#  '20201202',
#  '20201201',
#  '20201128',
#  '20201127',
#  '20201125',
#  '20201124',
#  '20201121']

# %%
# the dictionary data_dict has the flight date as the keys and data frame with flight information as the values
data_dict = {}
i = 0
for ymd in tab_name:
    data_dict[ymd] = df[i][0]
    i =i+1

# %%
data_dict['20201217']
# Out:
#                                    فترة زمنية (+04)+04  \
# 0                                              Airline
# 1    خ 11:27:0011:27ص غادرت البوابة (CGK) @ الخميس ...
# 2                                    FlightAware ADS-B
# 3    خ 11:27:1911:27ص المغادرة (CGK) @ الخميس 14:27...
# 4                                     خ 11:27:1911:27ص
# ..                                                 ...
# 100                                   خ 12:35:3212:35م
# 101                                   خ 12:36:4912:36م
# 102                                   خ 12:39:0212:39م
# 103                                   خ 12:40:1512:40م
# 104                                   خ 12:41:3312:41م
#
#                                         خط العرضخط عرض  \
# 0                                              Airline
# 1    خ 11:27:0011:27ص غادرت البوابة (CGK) @ الخميس ...
# 2                                    FlightAware ADS-B
# 3    خ 11:27:1911:27ص المغادرة (CGK) @ الخميس 14:27...
# 4                                         -6.1168-6.12
# ..                                                 ...
# 100                                       -0.1507-0.15
# 101                                       -0.1507-0.15
# 102                                       -0.1507-0.15
# 103                                       -0.1507-0.15
# 104                                       -0.1507-0.15
#
#                                       خط الطولخط الطول  \
# 0                                              Airline
# 1    خ 11:27:0011:27ص غادرت البوابة (CGK) @ الخميس ...
# 2                                    FlightAware ADS-B
# 3    خ 11:27:1911:27ص المغادرة (CGK) @ الخميس 14:27...
# 4                                       106.6496106.65
# ..                                                 ...
# 100                                     109.4039109.40
# 101                                     109.4039109.40
# 102                                     109.4039109.40
# 103                                     109.4039109.40
# 104                                     109.4039109.40
#
#                                         الاتجاهالاتجاه  \
# 0                                              Airline
# 1    خ 11:27:0011:27ص غادرت البوابة (CGK) @ الخميس ...
# 2                                    FlightAware ADS-B
# 3    خ 11:27:1911:27ص المغادرة (CGK) @ الخميس 14:27...
# 4                                               ← 248°
# ..                                                 ...
# 100                                              → 90°
# 101                                              → 90°
# 102                                              → 90°
# 103                                              → 90°
# 104                                              → 90°
#
#                                                   عقدة  \
# 0                                              Airline
# 1    خ 11:27:0011:27ص غادرت البوابة (CGK) @ الخميس ...
# 2                                    FlightAware ADS-B
# 3    خ 11:27:1911:27ص المغادرة (CGK) @ الخميس 14:27...
# 4                                                  151
# ..                                                 ...
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
#
#                                          كيلومتر/ ساعة   أمتار  معدل السرعة  \
# 0                                              Airline     NaN          NaN
# 1    خ 11:27:0011:27ص غادرت البوابة (CGK) @ الخميس ...     NaN          NaN
# 2                                    FlightAware ADS-B     NaN          NaN
# 3    خ 11:27:1911:27ص المغادرة (CGK) @ الخميس 14:27...     NaN          NaN
# 4                                                  280  9999.0          NaN
# ..                                                 ...     ...          ...
# 100                                                NaN     NaN          NaN
# 101                                                NaN     NaN          NaN
# 102                                                NaN     NaN          NaN
# 103                                                NaN     NaN          NaN
# 104                                                NaN     NaN          NaN
#
#                  مرفق التبليغ
# 0                         NaN
# 1                     Airline
# 2                         NaN
# 3    FlightAware ADS-B (WIRR)
# 4    FlightAware ADS-B (WIRR)
# ..                        ...
# 100                 Estimated
# 101                 Estimated
# 102                 Estimated
# 103                 Estimated
# 104                 Estimated
#
# [105 rows x 9 columns]

# %%
# save the original copy of data_dict in safe_data_dict
import copy
safe_data_dict = copy.deepcopy(data_dict)
# now, the data_dict can be modified; the original values will be intact in safe_data_dict

# %%
data_dict['20201217'].columns
# Out:
# Index(['فترة زمنية (+04)+04', 'خط العرضخط عرض', 'خط الطولخط الطول',
#        'الاتجاهالاتجاه', 'عقدة', 'كيلومتر/ ساعة', 'أمتار', 'معدل السرعة',
#        'مرفق التبليغ'],
#       dtype='object')

# %%
# rename the column titles in the English language
for dl in tab_name:
    data_dict[dl].set_axis(['Time', 'Latitude', 'Longitude', 'Heading', 'Kts', 'km/h', 'Altitude', 'RoC', 'Reporting Facility'], 
                axis = 1, inplace = True)

# %%
data_dict['20201217']
# Out:
#                                                   Time  \
# 0                                              Airline
# 1    خ 11:27:0011:27ص غادرت البوابة (CGK) @ الخميس ...
# 2                                    FlightAware ADS-B
# 3    خ 11:27:1911:27ص المغادرة (CGK) @ الخميس 14:27...
# 4                                     خ 11:27:1911:27ص
# ..                                                 ...
# 100                                   خ 12:35:3212:35م
# 101                                   خ 12:36:4912:36م
# 102                                   خ 12:39:0212:39م
# 103                                   خ 12:40:1512:40م
# 104                                   خ 12:41:3312:41م
#
#                                               Latitude  \
# 0                                              Airline
# 1    خ 11:27:0011:27ص غادرت البوابة (CGK) @ الخميس ...
# 2                                    FlightAware ADS-B
# 3    خ 11:27:1911:27ص المغادرة (CGK) @ الخميس 14:27...
# 4                                         -6.1168-6.12
# ..                                                 ...
# 100                                       -0.1507-0.15
# 101                                       -0.1507-0.15
# 102                                       -0.1507-0.15
# 103                                       -0.1507-0.15
# 104                                       -0.1507-0.15
#
#                                              Longitude  \
# 0                                              Airline
# 1    خ 11:27:0011:27ص غادرت البوابة (CGK) @ الخميس ...
# 2                                    FlightAware ADS-B
# 3    خ 11:27:1911:27ص المغادرة (CGK) @ الخميس 14:27...
# 4                                       106.6496106.65
# ..                                                 ...
# 100                                     109.4039109.40
# 101                                     109.4039109.40
# 102                                     109.4039109.40
# 103                                     109.4039109.40
# 104                                     109.4039109.40
#
#                                                Heading  \
# 0                                              Airline
# 1    خ 11:27:0011:27ص غادرت البوابة (CGK) @ الخميس ...
# 2                                    FlightAware ADS-B
# 3    خ 11:27:1911:27ص المغادرة (CGK) @ الخميس 14:27...
# 4                                               ← 248°
# ..                                                 ...
# 100                                              → 90°
# 101                                              → 90°
# 102                                              → 90°
# 103                                              → 90°
# 104                                              → 90°
#
#                                                    Kts  \
# 0                                              Airline
# 1    خ 11:27:0011:27ص غادرت البوابة (CGK) @ الخميس ...
# 2                                    FlightAware ADS-B
# 3    خ 11:27:1911:27ص المغادرة (CGK) @ الخميس 14:27...
# 4                                                  151
# ..                                                 ...
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
#
#                                                   km/h  Altitude  RoC  \
# 0                                              Airline       NaN  NaN
# 1    خ 11:27:0011:27ص غادرت البوابة (CGK) @ الخميس ...       NaN  NaN
# 2                                    FlightAware ADS-B       NaN  NaN
# 3    خ 11:27:1911:27ص المغادرة (CGK) @ الخميس 14:27...       NaN  NaN
# 4                                                  280    9999.0  NaN
# ..                                                 ...       ...  ...
# 100                                                NaN       NaN  NaN
# 101                                                NaN       NaN  NaN
# 102                                                NaN       NaN  NaN
# 103                                                NaN       NaN  NaN
# 104                                                NaN       NaN  NaN
#
#            Reporting Facility
# 0                         NaN
# 1                     Airline
# 2                         NaN
# 3    FlightAware ADS-B (WIRR)
# 4    FlightAware ADS-B (WIRR)
# ..                        ...
# 100                 Estimated
# 101                 Estimated
# 102                 Estimated
# 103                 Estimated
# 104                 Estimated
#
# [105 rows x 9 columns]

# %%
  
# drop the rows containing strings such as 'Gap in available data', 'FlightAware' and '@' in the 'Time' column
for dl in data_dict.values():
    
    idk1 = dl[dl['Time'].str.match('Gap in available data')].index
    idk2 = dl[dl['Time'].str.match('FlightAware')].index
    idk3 = dl[dl['Time'].str.contains('@')].index
    idk4 = dl[dl['Time'].str.contains('urface')].index
    idk5 = dl[dl['Latitude'].str.contains('Estimated')].index
    idk6 = dl[dl['Latitude'].str.contains('Airline')].index
    
    dl.drop(idk1, inplace = True)
    dl.drop(idk2, inplace = True)
    dl.drop(idk3, inplace = True)
    dl.drop(idk4, inplace = True)
    dl.drop(idk5, inplace = True)
    dl.drop(idk6, inplace = True)

# %%
def alt_maker(alt_col):
    dp_loc = alt_col.astype(str).str.find('.')
    # find the index of '.' 
    kp_loc = dp_loc//2
    # only one copy of the value is kept
    alt_val = []
   
   # The altitude column is of type float. It is converted into type object with each entry in the column as string.    
   
    str_alt_col = alt_col.apply(str)
   
    ctr = 0
    for elt in str_alt_col:
        new_alt = elt[0:kp_loc.iloc[ctr]]
        alt_val.append(new_alt)
        ctr=ctr+1
        
    # convert the string type of the altitude entries to float type
    altitude_vals = [float(item) for item in alt_val]
    return altitude_vals

# %%
# this function finds the index of the first decimal place in the entries of a column; then it keeps only the characters up
# to the 4th decimal place
def gps_format(frame):
    dec_loc = frame.str.find('.')
    dp_last = dec_loc + 5
    new_frame = []
    ct = 0
    for dx in frame:
        n_frame = dx[0:dp_last.iloc[ct]]
        new_frame.append(n_frame)
        ct = ct+1
      
    gps_val = [float(item) for item in new_frame]
    return gps_val

# %%
# reformat the 'Heading' or 'Course'
def head_maker(head_col):
    heading_col =[]
    for heading in head_col:
        if len(heading) <= 4:
            new_heading = heading[-3:-1].strip()
        else:
            new_heading = heading[-4:-1].strip()
        heading_col.append(new_heading)
    heading_vals = [float(item) for item in heading_col]
    return heading_vals

# %%
data_dict['20210109']
# Out:
#                     Time              Latitude             Longitude  \
# 3       س 11:36:1711:36ص          -6.1175-6.12        106.6474106.65
# 4       س 11:36:3411:36ص          -6.1220-6.12        106.6359106.64
# 5       س 11:36:5011:36ص          -6.1241-6.12        106.6231106.62
# 6       س 11:37:0611:37ص          -6.1189-6.12        106.6102106.61
# 7       س 11:37:2211:37ص          -6.1127-6.11        106.5957106.60
# 8       س 11:37:4911:37ص          -6.1045-6.10        106.5695106.57
# 9       س 11:38:0911:38ص          -6.0980-6.10        106.5487106.55
# 10      س 11:38:2911:38ص          -6.0839-6.08        106.5309106.53
# 11      س 11:38:4911:38ص          -6.0615-6.06        106.5228106.52
# 12      س 11:39:0811:39ص          -6.0384-6.04        106.5251106.53
# 13      س 11:39:3311:39ص          -6.0105-6.01        106.5408106.54
# 14      س 11:39:5811:39ص          -5.9870-5.99        106.5640106.56
# 15      س 11:40:1711:40ص          -5.9656-5.97        106.5657106.57
# 17      س 11:42:1311:42ص          -5.5678-5.57        106.7613106.76
# 18      س 11:43:1511:43ص          -5.3551-5.36        106.8657106.87
# 19      س 11:44:1611:44ص          -5.1459-5.15        106.9684106.97
# 20      س 11:45:1811:45ص          -4.9332-4.93        107.0727107.07
# 21      س 11:46:2211:46ص          -4.7136-4.71        107.1802107.18
# 22      س 11:47:2511:47ص          -4.4974-4.50        107.2861107.29
# 23      س 11:48:2911:48ص          -4.2778-4.28        107.3935107.39
# 24      س 11:50:2111:50ص          -3.8935-3.89        107.5814107.58
# 25      س 11:51:2311:51ص          -3.6807-3.68        107.6853107.69
# 26      س 11:52:3011:52ص          -3.4507-3.45        107.7976107.80
# 27      س 11:54:2911:54ص          -3.0423-3.04        107.9968108.00
# 28      س 11:55:2911:55ص          -2.8363-2.84        108.0973108.10
# 29      س 11:56:2911:56ص          -2.6303-2.63        108.1976108.20
# 30      س 11:58:2511:58ص          -2.2321-2.23        108.3916108.39
# 31      س 11:59:2511:59ص          -2.0261-2.03        108.4919108.49
# 32      س 12:00:2912:00م          -1.8064-1.81        108.5988108.60
# 33      س 12:02:2612:02م          -1.4047-1.40        108.7942108.79
# 34      س 12:03:2612:03م          -1.1987-1.20        108.8944108.89
# 35      س 12:05:2912:05م          -0.7763-0.78        109.0998109.10
# 36      س 12:07:2012:07م          -0.3952-0.40        109.2851109.29
# 37      س 12:09:1812:09م          -0.1507-0.15        109.4039109.40
# 38      س 12:11:1512:11م          -0.1507-0.15        109.4039109.40
# 39      س 12:13:1712:13م          -0.1507-0.15        109.4039109.40
# 40      س 12:15:1112:15م          -0.1507-0.15        109.4039109.40
# 41      س 12:16:1412:16م          -0.1507-0.15        109.4039109.40
# 42      س 12:17:1812:17م          -0.1507-0.15        109.4039109.40
# 43      س 12:18:2212:18م          -0.1507-0.15        109.4039109.40
# 44      س 12:19:2612:19م          -0.1507-0.15        109.4039109.40
# 45      س 12:21:2312:21م          -0.1507-0.15        109.4039109.40
# 48  وقت التدرج: 10 دقيقة  وقت التدرج: 10 دقيقة  وقت التدرج: 10 دقيقة
#
#                  Heading                   Kts                  km/h  \
# 3                 ← 249°                   161                   298
# 4                 ← 248°                   151                   280
# 5                 ← 279°                   182                   336
# 6                 ← 297°                   205                   380
# 7                 ← 290°                   219                   406
# 8                 ← 286°                   226                   418
# 9                 ← 292°                   232                   430
# 10          &nwarr; 324°                   242                   447
# 11                ↑ 352°                   257                   476
# 12                 ↑ 16°                   272                   504
# 13           &nearr; 41°                   285                   528
# 14           &nearr; 36°                   288                   533
# 15                ↑ 346°                   149                   275
# 17           &nearr; 26°                   NaN                   NaN
# 18           &nearr; 26°                   NaN                   NaN
# 19           &nearr; 26°                   NaN                   NaN
# 20           &nearr; 26°                   NaN                   NaN
# 21           &nearr; 26°                   NaN                   NaN
# 22           &nearr; 26°                   NaN                   NaN
# 23           &nearr; 26°                   NaN                   NaN
# 24           &nearr; 26°                   NaN                   NaN
# 25           &nearr; 26°                   NaN                   NaN
# 26           &nearr; 26°                   NaN                   NaN
# 27           &nearr; 26°                   NaN                   NaN
# 28           &nearr; 26°                   NaN                   NaN
# 29           &nearr; 26°                   NaN                   NaN
# 30           &nearr; 26°                   NaN                   NaN
# 31           &nearr; 26°                   NaN                   NaN
# 32           &nearr; 26°                   NaN                   NaN
# 33           &nearr; 26°                   NaN                   NaN
# 34           &nearr; 26°                   NaN                   NaN
# 35           &nearr; 26°                   NaN                   NaN
# 36           &nearr; 26°                   NaN                   NaN
# 37           &nearr; 26°                   NaN                   NaN
# 38                 → 90°                   NaN                   NaN
# 39                 → 90°                   NaN                   NaN
# 40                 → 90°                   NaN                   NaN
# 41                 → 90°                   NaN                   NaN
# 42                 → 90°                   NaN                   NaN
# 43                 → 90°                   NaN                   NaN
# 44                 → 90°                   NaN                   NaN
# 45                 → 90°                   NaN                   NaN
# 48  وقت التدرج: 10 دقيقة  وقت التدرج: 10 دقيقة  وقت التدرج: 10 دقيقة
#
#       Altitude     RoC              Reporting Facility
# 3     175175.0     NaN        FlightAware ADS-B (WIRR)
# 4     457457.0   776.0  FlightAware ADS-B (PCB / WIHP)
# 5     602602.0   529.0        FlightAware ADS-B (WIRR)
# 6     739739.0   757.0        FlightAware ADS-B (WIRR)
# 7   10061006.0  1063.0        FlightAware ADS-B (WIRR)
# 8   15011501.0  1138.0  FlightAware ADS-B (PCB / WIHP)
# 9   18971897.0  1189.0  FlightAware ADS-B (PCB / WIHP)
# 10  22942294.0  1063.0  FlightAware ADS-B (HLP / WIHH)
# 11  26062606.0   879.0  FlightAware ADS-B (HLP / WIHH)
# 12  28652865.0   717.0  FlightAware ADS-B (CGK / WIII)
# 13  31323132.0   530.0  FlightAware ADS-B (HLP / WIHH)
# 14  33073307.0 -1330.0  FlightAware ADS-B (PCB / WIHP)
# 15  21562156.0 -3634.0  FlightAware ADS-B (PCB / WIHP)
# 17         NaN     NaN                       Estimated
# 18         NaN     NaN                       Estimated
# 19         NaN     NaN                       Estimated
# 20         NaN     NaN                       Estimated
# 21         NaN     NaN                       Estimated
# 22         NaN     NaN                       Estimated
# 23         NaN     NaN                       Estimated
# 24         NaN     NaN                       Estimated
# 25         NaN     NaN                       Estimated
# 26         NaN     NaN                       Estimated
# 27         NaN     NaN                       Estimated
# 28         NaN     NaN                       Estimated
# 29         NaN     NaN                       Estimated
# 30         NaN     NaN                       Estimated
# 31         NaN     NaN                       Estimated
# 32         NaN     NaN                       Estimated
# 33         NaN     NaN                       Estimated
# 34         NaN     NaN                       Estimated
# 35         NaN     NaN                       Estimated
# 36         NaN     NaN                       Estimated
# 37         NaN     NaN                       Estimated
# 38         NaN     NaN                       Estimated
# 39         NaN     NaN                       Estimated
# 40         NaN     NaN                       Estimated
# 41         NaN     NaN                       Estimated
# 42         NaN     NaN                       Estimated
# 43         NaN     NaN                       Estimated
# 44         NaN     NaN                       Estimated
# 45         NaN     NaN                       Estimated
# 48         NaN     NaN                             NaN

# %%
# discard the rows which contain NaN under Reporting Facility
for dl in data_dict.values():
    dl = dl.dropna(subset = ["Reporting Facility"], inplace = True)
for dl in data_dict.values():
    xj = dl[dl['Reporting Facility'].str.match('Estimated')].index
    dl.drop(xj, inplace = True)

# %%
for dl in data_dict.values():
    # reformat the GPS coordinates given in the raw data. The gps_format function is defined in the previous cell.
    dl['Latitude'] = gps_format(dl['Latitude'])
    dl['Longitude'] = gps_format(dl['Longitude'])
    # keep only the first copy of the altitude values
    dl['Altitude'] = alt_maker(dl['Altitude'])
    dl['Heading'] = head_maker(dl['Heading'])

# %%
data_dict['20201217'].head()
# Out:
#                Time  Latitude  Longitude  Heading  Kts km/h  Altitude    RoC  \
# 4  خ 11:27:1911:27ص   -6.1168   106.6496    248.0  151  280      99.0    NaN
# 5  خ 11:27:3611:27ص   -6.1212   106.6388    248.0  157  291     282.0  707.0
# 6  خ 11:27:5211:27ص   -6.1252   106.6270    262.0  156  290     488.0  557.0
# 7  خ 11:28:0811:28ص   -6.1229   106.6161    291.0  173  320     579.0  343.0
# 8  خ 11:28:2411:28ص   -6.1178   106.6035    291.0  192  356     671.0  343.0
#
#                Reporting Facility
# 4        FlightAware ADS-B (WIRR)
# 5        FlightAware ADS-B (WIRR)
# 6  FlightAware ADS-B (HLP / WIHH)
# 7  FlightAware ADS-B (CGK / WIII)
# 8  FlightAware ADS-B (CGK / WIII)

# %%
data_dict['20201217'].tail()
# Out:
#                 Time  Latitude  Longitude  Heading  Kts km/h  Altitude  RoC  \
# 61  خ 11:54:5111:54ص   -3.4138   107.7225     25.0  451  835   10668.0  NaN
# 62  خ 11:55:4611:55ص   -3.3113   107.7696     25.0  451  835   10668.0  NaN
# 63  خ 11:56:2311:56ص   -3.2419   107.8014     25.0  445  824   10668.0  NaN
# 71  خ 12:03:4212:03م   -2.4023   108.1871     25.0  454  840   10668.0  NaN
# 72  خ 12:04:3912:04م   -2.2934   108.2371     25.0  452  837   10668.0  NaN
#
#                 Reporting Facility
# 61  FlightAware ADS-B (PCB / WIHP)
# 62  FlightAware ADS-B (HLP / WIHH)
# 63  FlightAware ADS-B (PCB / WIHP)
# 71  FlightAware ADS-B (HLP / WIHH)
# 72  FlightAware ADS-B (HLP / WIHH)

# %%
# extract time written in 24 hour format
def time_col(frame):
    l = []
    for r_time in frame:
        new_time = r_time[1:10].strip()
        l.append(new_time)
    return l

# %%
# format data in the time columns of all data
for dl in data_dict.values():
    dl['Time'] = time_col(dl['Time'])

# %%
data_dict['20201217'].head()
# Out:
#        Time  Latitude  Longitude  Heading  Kts km/h  Altitude    RoC  \
# 4  11:27:19   -6.1168   106.6496    248.0  151  280      99.0    NaN
# 5  11:27:36   -6.1212   106.6388    248.0  157  291     282.0  707.0
# 6  11:27:52   -6.1252   106.6270    262.0  156  290     488.0  557.0
# 7  11:28:08   -6.1229   106.6161    291.0  173  320     579.0  343.0
# 8  11:28:24   -6.1178   106.6035    291.0  192  356     671.0  343.0
#
#                Reporting Facility
# 4        FlightAware ADS-B (WIRR)
# 5        FlightAware ADS-B (WIRR)
# 6  FlightAware ADS-B (HLP / WIHH)
# 7  FlightAware ADS-B (CGK / WIII)
# 8  FlightAware ADS-B (CGK / WIII)

# %%
# from the time listed in the 24 Hour format, obtain the flight time.
def flight_time(frame):
    frame['time_stamp'] = pd.to_datetime(frame['Time'])
    # obtain initial reference time in minutes
    t0_hour_2_min = frame['time_stamp'].iloc[0].hour*60
    t0_min = frame['time_stamp'].iloc[0].minute
    t0_second_2_min = frame['time_stamp'].iloc[0].second/60
    t0_in_min = t0_hour_2_min + t0_min + t0_second_2_min
    
    t_elapse = []
    
    for one_time_val in frame['time_stamp']:
    # calculate absolute time in minutes for each entry
        t1_hour_2_min = one_time_val.hour*60
        t1_min = one_time_val.minute
        t1_second_2_min = one_time_val.second/60
        abs_time = t1_hour_2_min + t1_min + t1_second_2_min
        del_t = abs_time - t0_in_min
        # Inorder to account for the flights which departed at PM and landed at AM
        if del_t < 0:
            del_t = del_t + 24*60
        t_elapse.append(del_t)
    return t_elapse

# %%
# calculate the flight time in minutes for all data
for dl in data_dict.values():
    dl['Flight Time'] = flight_time(dl)

# %%
data_dict[tab_name[0]].tail()
# Out:
#         Time  Latitude  Longitude  Heading  Kts km/h  Altitude     RoC  \
# 11  11:38:49   -6.0615   106.5228    352.0  257  476    2606.0   879.0
# 12  11:39:08   -6.0384   106.5251     16.0  272  504    2865.0   717.0
# 13  11:39:33   -6.0105   106.5408     41.0  285  528    3132.0   530.0
# 14  11:39:58   -5.9870   106.5640     36.0  288  533    3307.0 -1330.0
# 15  11:40:17   -5.9656   106.5657    346.0  149  275    2156.0 -3634.0
#
#                 Reporting Facility          time_stamp  Flight Time
# 11  FlightAware ADS-B (HLP / WIHH) 2021-03-06 11:38:49     2.533333
# 12  FlightAware ADS-B (CGK / WIII) 2021-03-06 11:39:08     2.850000
# 13  FlightAware ADS-B (HLP / WIHH) 2021-03-06 11:39:33     3.266667
# 14  FlightAware ADS-B (PCB / WIHP) 2021-03-06 11:39:58     3.683333
# 15  FlightAware ADS-B (PCB / WIHP) 2021-03-06 11:40:17     4.000000

# %%
tab_name
# Out:
# ['20210109',
#  '20210104',
#  '20201217',
#  '20201215',
#  '20201212',
#  '20201210',
#  '20201205',
#  '20201203',
#  '20201202',
#  '20201201',
#  '20201128',
#  '20201127',
#  '20201125',
#  '20201124',
#  '20201121']

# %%
#from matplotlib import cm
cases = tab_name
#color_id = np.linspace(0, 1, len(tab_name))
#colors = [cm.rainbow(id) for id in color_id]

colors = ['black', 'firebrick', 'grey', 'lightcoral', 'orange', 'darkgoldenrod', 'darkkhaki',\
           'yellowgreen', 'lime', 'turquoise','teal', 'deepskyblue', 'deeppink', 'blue', 'red']

# %%
tkof=0
crz = 20
def plot_func(xax, yax, xlab, ylab,figname, dltarget, zoom, scat):
    fig = plt.figure(figsize = (15,10))
    ax1 = fig.add_subplot(111)
    ci = 0
    if zoom == 1:
        for dl in data_dict.values():
            ax1.plot(dl[xax][tkof:crz], dl[yax][tkof:crz], label =cases[ci], color = colors[ci])
            ci = ci+1
    
            ax1.legend(fontsize = 20)
    else:
        for dl in data_dict.values():
            ax1.plot(dl[xax], dl[yax], label =cases[ci], color = colors[ci])
            ci = ci+1
    
            ax1.legend(fontsize = 20)
        
    if scat == 1:
        ax1.plot(dltarget[xax][tkof:crz], dltarget[yax][tkof:crz],'o',color = colors[0])
    else:
        pass
    
    plt.ylabel(ylab, {'color': 'k', 'fontsize': 20})
    plt.xlabel(xlab, {'color': 'k', 'fontsize': 20})
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.minorticks_on()
    plt.grid(b=True, which='both', color='#999999', linestyle='-', alpha=0.25)
    # save figure should be called before showing the figure
    plt.savefig(figname, dpi = 400)
    plt.show()

# %%
plot_func('Flight Time', 'Altitude', 'Duration [min]','Altitude [m]',"SJY182_Altitude Plot.pdf",data_dict['20210109'] ,0, 0)

# %%
plot_func('Flight Time', 'Altitude', 'Duration [min]','Altitude [m]',"SJY182_Altitude Zoom Plot.pdf",data_dict['20210109'] ,\
          1, 1)

# %%
for dl in data_dict.values():
    dl['km/h'] = dl['km/h'].apply(pd.to_numeric, downcast='float', errors='coerce')

# %%
plot_func('Flight Time', 'km/h', 'Duration [min]','Speed [km/h]',"SJY182_Ground Speed Zoom Plot.pdf",\
          data_dict['20210109'] ,1, 1)

# %%
plot_func('Flight Time', 'RoC', 'Duration [min]','RoC [m/min]',"SJY182_RoC Zoom Plot.pdf",data_dict['20210109'] ,1, 1)

# %%
plot_func('Flight Time', 'Heading', 'Duration [min]','Heading [deg]',"SJY182_Heading Zoom Plot.pdf",\
          data_dict['20210109'] ,1, 1)

# %%
# polar plot to depict the heading
ci = 0
fig = plt.figure(figsize = (15,10))
ax = fig.add_subplot(111, projection='polar')
for dl in data_dict.values():
    r = dl['Flight Time'][tkof:crz]
    theta = np.deg2rad(dl['Heading'][tkof:crz])
    ax.plot(theta, r,alpha=0.9, color = colors[ci])
    ci = ci+1

# %%
for dset in data_dict.values():
    speed_ms = dset['km/h']*(1000/60) # speed in meters per minute
    dv_du = dset['RoC']/speed_ms # ratio of vertical speed to ground speed
    dset['Inclination'] = np.rad2deg(np.arcsin(dv_du))

# %%
data_dict['20210109']
# Out:
#         Time  Latitude  Longitude  Heading  Kts   km/h  Altitude     RoC  \
# 3   11:36:17   -6.1175   106.6474    249.0  161  298.0     175.0     NaN
# 4   11:36:34   -6.1220   106.6359    248.0  151  280.0     457.0   776.0
# 5   11:36:50   -6.1241   106.6231    279.0  182  336.0     602.0   529.0
# 6   11:37:06   -6.1189   106.6102    297.0  205  380.0     739.0   757.0
# 7   11:37:22   -6.1127   106.5957    290.0  219  406.0    1006.0  1063.0
# 8   11:37:49   -6.1045   106.5695    286.0  226  418.0    1501.0  1138.0
# 9   11:38:09   -6.0980   106.5487    292.0  232  430.0    1897.0  1189.0
# 10  11:38:29   -6.0839   106.5309    324.0  242  447.0    2294.0  1063.0
# 11  11:38:49   -6.0615   106.5228    352.0  257  476.0    2606.0   879.0
# 12  11:39:08   -6.0384   106.5251     16.0  272  504.0    2865.0   717.0
# 13  11:39:33   -6.0105   106.5408     41.0  285  528.0    3132.0   530.0
# 14  11:39:58   -5.9870   106.5640     36.0  288  533.0    3307.0 -1330.0
# 15  11:40:17   -5.9656   106.5657    346.0  149  275.0    2156.0 -3634.0
#
#                 Reporting Facility          time_stamp  Flight Time  \
# 3         FlightAware ADS-B (WIRR) 2021-03-06 11:36:17     0.000000
# 4   FlightAware ADS-B (PCB / WIHP) 2021-03-06 11:36:34     0.283333
# 5         FlightAware ADS-B (WIRR) 2021-03-06 11:36:50     0.550000
# 6         FlightAware ADS-B (WIRR) 2021-03-06 11:37:06     0.816667
# 7         FlightAware ADS-B (WIRR) 2021-03-06 11:37:22     1.083333
# 8   FlightAware ADS-B (PCB / WIHP) 2021-03-06 11:37:49     1.533333
# 9   FlightAware ADS-B (PCB / WIHP) 2021-03-06 11:38:09     1.866667
# 10  FlightAware ADS-B (HLP / WIHH) 2021-03-06 11:38:29     2.200000
# 11  FlightAware ADS-B (HLP / WIHH) 2021-03-06 11:38:49     2.533333
# 12  FlightAware ADS-B (CGK / WIII) 2021-03-06 11:39:08     2.850000
# 13  FlightAware ADS-B (HLP / WIHH) 2021-03-06 11:39:33     3.266667
# 14  FlightAware ADS-B (PCB / WIHP) 2021-03-06 11:39:58     3.683333
# 15  FlightAware ADS-B (PCB / WIHP) 2021-03-06 11:40:17     4.000000
#
#     Inclination
# 3           NaN
# 4      9.571932
# 5      5.420487
# 6      6.864766
# 7      9.038238
# 8      9.401354
# 9      9.549927
# 10     8.203220
# 11     6.361337
# 12     4.896562
# 13     3.452858
# 14    -8.610618
# 15   -52.454789

# %%
plot_func('Flight Time', 'Inclination', 'Duration [min]','Inclination [Deg]',"SJY182_Inclination Zoom Plot.pdf",
          data_dict['20210109'] ,1, 1)

# %%
ci = 0
fig = plt.figure(figsize = (30,10))
ax = fig.add_subplot(111, projection='polar')
for dl in data_dict.values():
    r = dl['Flight Time'][tkof:crz]
    theta = np.deg2rad(dl['Inclination'][tkof:crz])
    ax.plot(theta, r,alpha=0.9, color = colors[ci])

    ci = ci+1
ax.set_thetamin(-60)
ax.set_thetamax(20)
plt.show()
# Out:
# C:\Users\Utsav\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\projections\polar.py:55: RuntimeWarning: invalid value encountered in greater_equal
#   r = np.where(r >= 0, r, np.nan)

# %%
# plot in google maps
import gmplot

# %%
api_key = 'AIzaSyB7oTbmcoJX6oSUKSjJj3r5csCUEitIv8M'
gmap = gmplot.GoogleMapPlotter(-6.1175, 106.6474, 13, apikey=api_key)

# %%
ci = 0
for dl in data_dict.values():
    gmap.plot(dl['Latitude'],dl['Longitude'], color = colors[ci], edge_width = 2.5)
    ci = ci+1

# %%
gmap.draw('SJY182flight_path.html')
import os
os.system('SJY182flight_path.html')
# Out:
# 0
